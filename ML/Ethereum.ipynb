# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
import json
from prophet.serialize import model_to_json, model_from_json

# %%
DataSet = pd.read_csv('Data\Ethereum.csv')
DataSet.head()
# Out:
#          Date    Open    High     Low   Close      Volume    Market Cap
# 0  07-08-2015  180.46  225.37  160.69  176.66  10472802.0  1.061821e+10
# 1  08-08-2015  178.04  178.37   45.55   48.01  42965462.0  2.898843e+09
# 2  09-08-2015   45.00   56.07   40.10   44.74  33914768.0  2.702091e+09
# 3  10-08-2015   45.51   46.53   40.58   45.22  25834765.0  2.729457e+09
# 4  11-08-2015   45.20   72.81   42.53   68.69  93398013.0  4.121826e+09

# %%
DataSet.rename(columns={'Date': 'ds'}, inplace=True)
DataSet.rename(columns={'Close': 'y'}, inplace=True)
DataSet.head()
# Out:
#            ds    Open    High     Low       y      Volume    Market Cap
# 0  07-08-2015  180.46  225.37  160.69  176.66  10472802.0  1.061821e+10
# 1  08-08-2015  178.04  178.37   45.55   48.01  42965462.0  2.898843e+09
# 2  09-08-2015   45.00   56.07   40.10   44.74  33914768.0  2.702091e+09
# 3  10-08-2015   45.51   46.53   40.58   45.22  25834765.0  2.729457e+09
# 4  11-08-2015   45.20   72.81   42.53   68.69  93398013.0  4.121826e+09

# %%
df = DataSet[['ds', 'y']]
df.head()
# Out:
#            ds       y
# 0  07-08-2015  176.66
# 1  08-08-2015   48.01
# 2  09-08-2015   44.74
# 3  10-08-2015   45.22
# 4  11-08-2015   68.69

# %%
m = Prophet()
m.fit(df)
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# ...
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 2823 2023-11-30
# 2824 2023-12-01
# 2825 2023-12-02
# 2826 2023-12-03
# 2827 2023-12-04

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds           yhat     yhat_lower     yhat_upper
# 2823 2023-11-30  468144.754145  422158.706047  512291.331385
# 2824 2023-12-01  468312.579122  420406.661599  513477.743483
# 2825 2023-12-02  466919.807924  420786.708687  512258.482266
# 2826 2023-12-03  467008.251427  417723.685671  510911.331525
# 2827 2023-12-04  466365.707699  416859.482931  512939.456607

# %%
plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
with open('models\Ethereum.json', 'w') as fout:
    json.dump(model_to_json(m), fout)
