# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
import json
from prophet.serialize import model_to_json, model_from_json

# %%
DataSet = pd.read_csv('Data\Xrp.csv')
DataSet.head()
# Out:
#          Date  Open  High   Low  Close     Volume   Market Cap
# 0  06-04-2020  4.98  5.75  2.97   3.78  2535081.0          0.0
# 1  07-04-2020  3.79  5.23  2.82   3.61  2935816.0          0.0
# 2  08-04-2020  3.68  4.11  1.23   2.74  3088644.0          0.0
# 3  09-04-2020  2.74  3.19  1.93   1.94  1616471.0          0.0
# 4  10-04-2020  1.93  2.61  1.07   2.03  2410784.0  181626782.0

# %%
DataSet.rename(columns={'Date': 'ds'}, inplace=True)
DataSet.rename(columns={'Close': 'y'}, inplace=True)
DataSet.head()
# Out:
#            ds  Open  High   Low     y     Volume   Market Cap
# 0  06-04-2020  4.98  5.75  2.97  3.78  2535081.0          0.0
# 1  07-04-2020  3.79  5.23  2.82  3.61  2935816.0          0.0
# 2  08-04-2020  3.68  4.11  1.23  2.74  3088644.0          0.0
# 3  09-04-2020  2.74  3.19  1.93  1.94  1616471.0          0.0
# 4  10-04-2020  1.93  2.61  1.07  2.03  2410784.0  181626782.0

# %%
df = DataSet[['ds', 'y']]
df.head()
# Out:
#            ds     y
# 0  06-04-2020  3.78
# 1  07-04-2020  3.61
# 2  08-04-2020  2.74
# 3  09-04-2020  1.94
# 4  10-04-2020  2.03

# %%
m = Prophet()
m.fit(df)
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# ...
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1119 2023-11-30
# 1120 2023-12-01
# 1121 2023-12-02
# 1122 2023-12-03
# 1123 2023-12-04

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds      yhat  yhat_lower  yhat_upper
# 1119 2023-11-30  1.029487    0.192392    1.905084
# 1120 2023-12-01  0.995841    0.154385    1.796830
# 1121 2023-12-02  1.018104    0.168498    1.858778
# 1122 2023-12-03  1.002247    0.089924    1.893972
# 1123 2023-12-04  0.944078    0.124999    1.796029

# %%
plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
with open('models\Xpr.json', 'w') as fout:
    json.dump(model_to_json(m), fout)
