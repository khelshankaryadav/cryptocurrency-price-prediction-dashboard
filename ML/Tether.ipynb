# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
import json
from prophet.serialize import model_to_json, model_from_json

# %%
DataSet = pd.read_csv('Data\Tether.csv')
DataSet.head()
# Out:
#          Date   Open   High    Low  Close       Volume  Market Cap
# 0  20-09-2019  71.49  71.54  70.87  71.31   18272044.0         0.0
# 1  21-09-2019  71.30  71.71  71.21  71.35   12308228.0         0.0
# 2  22-09-2019  71.37  71.71  71.10  71.42   10722938.0         0.0
# 3  23-09-2019  71.46  71.80  70.77  70.97  109095332.0         0.0
# 4  24-09-2019  70.97  75.21  70.61  71.49  291043870.0         0.0

# %%
DataSet.rename(columns={'Date': 'ds'}, inplace=True)
DataSet.rename(columns={'Close': 'y'}, inplace=True)
DataSet.head()
# Out:
#            ds   Open   High    Low      y       Volume  Market Cap
# 0  20-09-2019  71.49  71.54  70.87  71.31   18272044.0         0.0
# 1  21-09-2019  71.30  71.71  71.21  71.35   12308228.0         0.0
# 2  22-09-2019  71.37  71.71  71.10  71.42   10722938.0         0.0
# 3  23-09-2019  71.46  71.80  70.77  70.97  109095332.0         0.0
# 4  24-09-2019  70.97  75.21  70.61  71.49  291043870.0         0.0

# %%
df = DataSet[['ds', 'y']]
df.head()
# Out:
#            ds      y
# 0  20-09-2019  71.31
# 1  21-09-2019  71.35
# 2  22-09-2019  71.42
# 3  23-09-2019  70.97
# 4  24-09-2019  71.49

# %%
m = Prophet()
m.fit(df)
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '15-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '16-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '17-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '18-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '19-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '20-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '21-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '22-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '23-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '24-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '25-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '26-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '27-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '28-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '29-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '30-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '31-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '13-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:1114: UserWarning: Parsing '14-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# ...
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '14-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '15-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '16-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '17-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '18-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '20-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '23-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '24-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '27-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '28-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '29-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:267: UserWarning: Parsing '30-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['ds'] = pd.to_datetime(df['ds'])
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1318 2023-11-30
# 1319 2023-12-01
# 1320 2023-12-02
# 1321 2023-12-03
# 1322 2023-12-04

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds       yhat  yhat_lower  yhat_upper
# 1318 2023-11-30  77.137039   74.493395   80.088508
# 1319 2023-12-01  77.159538   74.616060   80.037005
# 1320 2023-12-02  77.135653   74.524934   79.845383
# 1321 2023-12-03  77.096822   74.431643   80.095032
# 1322 2023-12-04  76.996581   74.358372   79.854406

# %%
plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)
# Out:
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\khels\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
with open('models\Tether.json', 'w') as fout:
    json.dump(model_to_json(m), fout)
